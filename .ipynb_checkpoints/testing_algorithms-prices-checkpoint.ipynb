# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
#import data here 

train_data = pd.read_csv('./train_noclean.csv')
test_data = pd.read_csv('./test_noclean.csv')

y_train = train_data.loc[:,'price']
train_data = train_data.drop(columns='price')
num_features = len(train_data.columns)
features = list(train_data.columns[2:num_features])
X_train = train_data.loc[:,features]

features = list(test_data.columns[2:num_features])

X_test = test_data.loc[:,features]
test_labels = test_data.loc[:,'id']

test_labels = test_labels.to_frame()

# %%
from sklearn.neural_network import MLPClassifier

kf = KFold(n_splits = 10, shuffle=True)


X = np.concatenate([X_train], axis= 0)
y = np.concatenate([y_train], axis= 0)

for train, test in kf.split(X_train):
    X_train_kf, X_test_kf = X[train],X[test]
    y_train_kf, y_test_kf = y[train],y[test]
    
    clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train) 
    clf_predictions = clf.predict(X_test_kf) 
    accuracy = clf.score(X_test_kf, y_test_kf)
    print(accuracy)
# Out:
# 0.43653250773993807
# 0.43285123966942146
# 0.4597107438016529
# 0.42768595041322316
# 0.42768595041322316
# 0.4390495867768595
# 0.4628099173553719
# 0.4607438016528926
# 0.43491735537190085
# 0.43491735537190085

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

kf = KFold(n_splits = 10, shuffle=True)

param_grid = {'bootstrap': [True, False],
 'criterion': ['gini', 'entropy'],
 'max_depth': [2, 5, 10, 20, 30, None],
 'max_features': ['auto', 'sqrt'],
 'min_samples_leaf': [1, 2, 4],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [50, 100, 200, 400, 600, 800, 1000, 1200, 1500, 2000]}
X = np.concatenate([X_train], axis= 0)
y = np.concatenate([y_train], axis= 0)


clf = RandomForestClassifier()  
rsearch = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, cv=kf, n_iter = 1000, n_jobs = -1, verbose=10)
clf_model = rsearch.fit(X=X, y=y)

print(clf_model.best_params_, clf_model.best_score_)
# Out:
# Fitting 10 folds for each of 1000 candidates, totalling 10000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   38.8s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed:  5.4min
# /opt/conda/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 6813 tasks      | elapsed: 110.9min
# [Parallel(n_jobs=-1)]: Done 6930 tasks      | elapsed: 112.7min
# [Parallel(n_jobs=-1)]: Done 7049 tasks      | elapsed: 113.6min
# [Parallel(n_jobs=-1)]: Done 7168 tasks      | elapsed: 116.3min
# [Parallel(n_jobs=-1)]: Done 7289 tasks      | elapsed: 119.4min
# [Parallel(n_jobs=-1)]: Done 7410 tasks      | elapsed: 121.6min
# [Parallel(n_jobs=-1)]: Done 7533 tasks      | elapsed: 123.7min
# [Parallel(n_jobs=-1)]: Done 7656 tasks      | elapsed: 124.6min
# [Parallel(n_jobs=-1)]: Done 7781 tasks      | elapsed: 127.2min
# [Parallel(n_jobs=-1)]: Done 7906 tasks      | elapsed: 129.7min
# [Parallel(n_jobs=-1)]: Done 8033 tasks      | elapsed: 131.8min
# [Parallel(n_jobs=-1)]: Done 8160 tasks      | elapsed: 133.4min
# [Parallel(n_jobs=-1)]: Done 8289 tasks      | elapsed: 135.8min
# [Parallel(n_jobs=-1)]: Done 8418 tasks      | elapsed: 137.3min
# [Parallel(n_jobs=-1)]: Done 8549 tasks      | elapsed: 139.1min
# [Parallel(n_jobs=-1)]: Done 8680 tasks      | elapsed: 141.4min
# [Parallel(n_jobs=-1)]: Done 8813 tasks      | elapsed: 143.9min
# [Parallel(n_jobs=-1)]: Done 8946 tasks      | elapsed: 145.7min
# [Parallel(n_jobs=-1)]: Done 9081 tasks      | elapsed: 148.0min
# [Parallel(n_jobs=-1)]: Done 9216 tasks      | elapsed: 150.0min
# [Parallel(n_jobs=-1)]: Done 9353 tasks      | elapsed: 152.0min
# [Parallel(n_jobs=-1)]: Done 9490 tasks      | elapsed: 153.9min
# [Parallel(n_jobs=-1)]: Done 9629 tasks      | elapsed: 155.4min
# [Parallel(n_jobs=-1)]: Done 9768 tasks      | elapsed: 157.1min
# [Parallel(n_jobs=-1)]: Done 9909 tasks      | elapsed: 159.5min
# [Parallel(n_jobs=-1)]: Done 10000 out of 10000 | elapsed: 161.3min finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-679893db68a2> in <module>
#      19 clf_model = rsearch.fit(X=X, y=y)
#      20
# ---> 21 print(lgb_model.best_params_, lgb_model.best_score_)
#
# NameError: name 'lgb_model' is not defined

# %%
print(clf_model.best_params_, clf_model.best_score_)
# Out:
# {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 20, 'criterion': 'gini', 'bootstrap': True} 0.5594477351619204

# %%
params = {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 20, 'criterion': 'gini', 'bootstrap': True}

clf = RandomForestClassifier()
clf.set_params(**params)
clf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=1000)

# %%
y_pred1=clf.predict(X)
print(y_pred1)
print(accuracy_score(y, y_pred1))
# Out:
# [2 1 3 ... 3 3 1]
# 0.9925627517818407

# %%
y_pred=clf.predict(X_test)

df = pd.DataFrame
test_labels['price'] = y_pred

test_labels['price'] = test_labels['price'].map(lambda x: int(x))

# %%
test_labels
# Out:
#          id  price
# 0      7715      2
# 1     13196      2
# 2     13194      2
# 3      4673      2
# 4     11325      1
# ...     ...    ...
# 4144  12921      2
# 4145   7174      2
# 4146   9240      3
# 4147  11663      1
# 4148   4513      1
#
# [4149 rows x 2 columns]

# %%
test_labels.to_csv(r'./submission13.csv', index=False)

# %%
from sklearn.naive_bayes import GaussianNB 

kf = KFold(n_splits = 10, shuffle=True)


X = np.concatenate([X_train], axis= 0)
y = np.concatenate([y_train], axis= 0)

for train, test in kf.split(X_train):
    X_train_kf, X_test_kf = X[train],X[test]
    y_train_kf, y_test_kf = y[train],y[test]
    
    gnb = GaussianNB().fit(X_train_kf, y_train_kf) 
    gnb_predictions = gnb.predict(X_test_kf) 
    accuracy = gnb.score(X_test_kf, y_test_kf)
    print(accuracy)
# Out:
# 0.3993808049535604
# 0.4049586776859504
# 0.4555785123966942
# 0.4132231404958678
# 0.40392561983471076
# 0.3977272727272727
# 0.42355371900826444
# 0.43078512396694213
# 0.42665289256198347
# 0.42458677685950413

# %%
from sklearn.svm import SVC 
kf = KFold(n_splits = 10, shuffle=True)


X = np.concatenate([X_train], axis= 0)
y = np.concatenate([y_train], axis= 0)

for train, test in kf.split(X_train):
    X_train_kf, X_test_kf = X[train],X[test]
    y_train_kf, y_test_kf = y[train],y[test]
    
    svm_model_linear = SVC(kernel = 'linear', C = 1).fit(X_train_kf, y_train_kf) 
    svm_predictions = svm_model_linear.predict(X_test_kf)  
    accuracy = svm_model_linear.score(X_test_kf, y_test_kf) 
    print(accuracy)

# %%
from sklearn.metrics import accuracy_score
import lightgbm as lgb
kf = KFold(n_splits = 10, shuffle=True)


X = np.concatenate([X_train], axis= 0)
y = np.concatenate([y_train], axis= 0)

for train, test in kf.split(X_train):
    X_train_kf, X_test_kf = X[train],X[test]
    y_train_kf, y_test_kf = y[train],y[test]
    d_train=lgb.Dataset(X_train_kf, label=y_train_kf)
    params={}
    params['learning_rate']=0.03
    params['boosting_type']='gbdt' #GradientBoostingDecisionTree
    params['objective']='multiclass' #Multi-class target feature
    params['metric']='multi_error' #metric for multi-class
    params['max_depth']=10
    params['num_class']=5
    clf=lgb.train(params,d_train,100)
    
    y_pred=clf.predict(X_test_kf)
    y_pred = [np.argmax(line) for line in y_pred]
    print(accuracy_score(y_test_kf, y_pred))

# %%
from keras.datasets import reuters
from keras import models
from keras import layers

# %%
kf = KFold(n_splits = 10, shuffle=True)
X = np.concatenate([X_train], axis= 0)
y = np.concatenate([y_train], axis= 0)

X = np.asarray(X).astype(np.float32)
y = np.asarray(y).astype(np.float32)
for train, test in kf.split(X_train):
    X_train_kf, X_test_kf = X[train],X[test]
    y_train_kf, y_test_kf = y[train],y[test]
    
    model = models.Sequential()
    model.add(layers.Dense(64, activation='tanh'))
    model.add(layers.Dense(64, activation='tanh'))
    model.add(layers.Dense(64, activation='tanh'))
    model.add(layers.Dense(46, activation='softmax'))


    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

    x_val = X_test_kf
    partial_x_train = X_train_kf
    y_val = y_test_kf
    partial_y_train = y_train_kf

    history = model.fit(partial_x_train, partial_y_train, epochs=9, batch_size=512, validation_data=(x_val, y_val))
b

    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, 10)
    plt.plot(epochs, loss, 'bo', label='Training_loss')
    plt.plot(epochs, val_loss, 'b', label='Validation_loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    plt.clf()
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    plt.plot(epochs, acc, 'bo', label='Training_accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validaion_accuracy')
    plt.legend()
    plt.show()
    print(accuracy)
